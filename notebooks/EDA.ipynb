# %% [markdown]
# # Jupyter notebook for the web app

# %%
import pandas as pd 
import plotly.express as px

# %%
base_path = '/home/fercho/Documents/Tripleten_repos/cars_project/'
car_data = pd.read_csv(base_path + 'vehicles_us.csv') # leer los datos
fig = px.histogram(car_data, x="odometer") # crear un histograma
fig.show() # crear gráfico de dispersión
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       2 car_data = pd.read_csv(base_path + 'vehicles_us.csv') # leer los datos
#       3 fig = px.histogram(car_data, x="odometer") # crear un histograma
# ----> 4 fig.show() # crear gráfico de dispersión
#
# File ~/miniconda3/envs/car-env/lib/python3.14/site-packages/plotly/basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)   3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File ~/miniconda3/envs/car-env/lib/python3.14/site-packages/plotly/io/_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
# ...

# %%
import sys
sys.executable
# Out:
# '/home/fercho/miniconda3/envs/car-env/bin/python'

# %%
import nbformat
nbformat.__version__
# Out:
# '5.10.4'
